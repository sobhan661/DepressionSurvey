# %% [markdown]
# First look at the dataset

# %% [markdown]
# Data set we are using is available here: https://www.kaggle.com/datasets/sunil123kumar/social-media-impact-on-mental-health

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
from data.processed.load_data import df

print(df.head())
print(df.describe())
print(df.info())

# Checking how many values depression_label contains
print(df["depression_label"].unique())

# %% [markdown]
# At the very first look it is obvious that the column depression_label can be the target for our ml training model. depression_label column has two unique values [0, 1] which tells us either you are depressed or you are not depressed
